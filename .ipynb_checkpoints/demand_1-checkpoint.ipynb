# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %%time
from influxdb import InfluxDBClient
from  credentials import *
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
import plotly.graph_objs as go

#import plotly.graph_objs as go
#from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler

import os
from tensorflow import keras 
from tensorflow.keras.models import Sequential
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import LSTM, Dense
# Out:
# Wall time: 1.29 s

# %%
#connect to Database
def get_connect():
    client = InfluxDBClient(host=host, port=port, username=username, password=password)
    client.switch_database('orkney')
    return client


#Query Data
def get_Demand_data():
    client = get_connect()
    Demand = client.query('SELECT * FROM "Demand" WHERE time > now() - 2200d ORDER BY time')
    values = Demand.raw["series"][0]["values"]
    columns = Demand.raw["series"][0]["columns"]
    Demand = pd.DataFrame(values, columns=columns)#.set_index("time")
    return Demand



def explore_data(df):
    #df = get_Demand_data()
    df['Datetime'] = pd.to_datetime(df.time)
    df['year'] = df.Datetime.dt.year
    df['month'] = df.Datetime.dt.month
    df['day']=  df.Datetime.dt.day
    df['Hour']= df.Datetime.dt.hour
    df = df.drop(["time","year","month","day","Hour"],axis=1)
    df = df.set_index("Datetime")

    return df 



df = get_Demand_data()
df = explore_data(df)
df.head(2)
# Out:
#                            Total
# Datetime
# 2016-02-26 02:09:59+00:00  16.56
# 2016-02-26 02:11:00+00:00  16.56

# %%
##################################
# %time
if not os.path.exists('model'):
    os.makedirs('model')

if not os.path.exists('img'):
    os.makedirs('img')



# Hardcode all variables
batch_size_exp = 1
epoch_exp = 5
neurons_exp = 10
predict_values_exp = 60*24*30 #next minute
lag_exp=5


# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]


# scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled

# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]


# fit an LSTM network to training data
def fit_lstm(train, batch_size=1, nb_epoch=5, neurons=10):
    # simple early stopping

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
    mc = ModelCheckpoint(filepath="model/model1.h5", save_best_only=True)
  
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
        
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False, callbacks=[mc,es])
        model.reset_states()
    model.save("model/model1.h5")
    return model
    #print(model.summary)

# make a one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    #print(X)
    yhat = model.predict(X, batch_size=1)
    return yhat[0,0]
# Out:
# Wall time: 0 ns

# %%
# %time

# transform data to be stationary
raw_values = df.values
diff_values = difference(raw_values, 1)

# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, lag_exp)
supervised_values = supervised.values

# split data into train and test-sets
train, test = supervised_values[0:-predict_values_exp], supervised_values[-predict_values_exp:]


# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# fit the model


lstm_model = fit_lstm(train_scaled, batch_size_exp, epoch_exp, neurons_exp)
# Out:
# Wall time: 0 ns
# 2374584/2374613 [============================>.] - ETA: 0s - loss: 2.6473e-04 - root_mean_squared_error: 0.0163WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,root_mean_squared_error
# 2374613/2374613 [==============================] - 4381s 2ms/step - loss: 2.6473e-04 - root_mean_squared_error: 0.0163
# 2374586/2374613 [============================>.] - ETA: 0s - loss: 2.6448e-04 - root_mean_squared_error: 0.0163WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,root_mean_squared_error
# 2374613/2374613 [==============================] - 3927s 2ms/step - loss: 2.6448e-04 - root_mean_squared_error: 0.0163
# 2374585/2374613 [============================>.] - ETA: 0s - loss: 2.6457e-04 - root_mean_squared_error: 0.0163WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,root_mean_squared_error
# 2374613/2374613 [==============================] - 3987s 2ms/step - loss: 2.6457e-04 - root_mean_squared_error: 0.0163
# 2374598/2374613 [============================>.] - ETA: 0s - loss: 2.6796e-04 - root_mean_squared_error: 0.0164WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,root_mean_squared_error
# 2374613/2374613 [==============================] - 3939s 2ms/step - loss: 2.6796e-04 - root_mean_squared_error: 0.0164
# 2374602/2374613 [============================>.] - ETA: 0s - loss: 2.6483e-04 - root_mean_squared_error: 0.0163WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,root_mean_squared_error
# 2374613/2374613 [==============================] - 3981s 2ms/step - loss: 2.6483e-04 - root_mean_squared_error: 0.0163

# %%
# walk-forward validation on the test data
predictions = list()
expectations = list()
predictions_plot = list()
expectations_plot = list()
test_pred = list()

for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)#batch_size_exp to 1

    # Replacing value in test scaled with the predicted value.
    test_pred = [yhat] + test_pred 
    if len(test_pred) > lag_exp+1:
        test_pred = test_pred[:-1]
    if i+1<len(test_scaled):
        if i+1 > lag_exp+1:
            test_scaled[i+1] = test_pred
        else:
            test_scaled[i+1] = np.concatenate((test_pred, test_scaled[i+1, i+1:]),axis=0)

    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
    # store forecast
    expected = raw_values[len(train) + i + 1]
    predictions_plot.append(yhat)
    expectations_plot.append(expected)
    if expected != 0:
        predictions.append(yhat)
        expectations.append(expected)

        
        
    print('Minute=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))


expectations = np.array(expectations)
predictions = np.array(predictions)

print("Mean Absolute Percent Error: ", (np.mean(np.abs((expectations - predictions) / expectations))))
# Out:
# Minute=1, Predicted=17.204669, Expected=17.310000
# Minute=2, Predicted=17.077319, Expected=17.310000
# Minute=3, Predicted=17.131942, Expected=17.310000
# Minute=4, Predicted=17.167376, Expected=17.310000
# Minute=5, Predicted=17.256241, Expected=18.670000
# Minute=6, Predicted=18.682776, Expected=18.670000
# Minute=7, Predicted=18.788099, Expected=18.670000
# Minute=8, Predicted=18.832369, Expected=18.670000
# Minute=9, Predicted=18.896680, Expected=18.670000
# Minute=10, Predicted=18.902348, Expected=18.670000
# Minute=11, Predicted=18.950711, Expected=18.670000
# Minute=12, Predicted=18.948734, Expected=20.240000
# Minute=13, Predicted=20.593573, Expected=20.240000
# Minute=14, Predicted=20.612527, Expected=20.240000
# Minute=15, Predicted=20.749622, Expected=20.240000
# Minute=16, Predicted=20.779559, Expected=20.240000
# Minute=17, Predicted=20.990157, Expected=20.240000
# Minute=18, Predicted=20.949523, Expected=20.240000
# Minute=19, Predicted=21.171871, Expected=20.240000
# Minute=20, Predicted=20.909492, Expected=19.910000
# Minute=21, Predicted=20.607550, Expected=19.910000
# Minute=22, Predicted=20.236092, Expected=19.910000
# Minute=23, Predicted=20.120441, Expected=19.910000
# Minute=24, Predicted=19.931506, Expected=19.910000
# Minute=25, Predicted=19.873913, Expected=19.910000
# Minute=26, Predicted=19.831170, Expected=19.910000
# Minute=27, Predicted=19.825946, Expected=18.730000
# Minute=28, Predicted=18.653268, Expected=18.730000
# Minute=29, Predicted=18.661796, Expected=18.730000
# Minute=30, Predicted=18.676200, Expected=18.730000
# Minute=31, Predicted=18.682736, Expected=18.730000
# Minute=32, Predicted=18.692789, Expected=18.730000
# Minute=33, Predicted=18.696220, Expected=18.730000
# Minute=34, Predicted=18.701560, Expected=19.430000
# Minute=35, Predicted=19.403521, Expected=19.430000
# Minute=36, Predicted=19.406036, Expected=19.430000
# Minute=37, Predicted=19.407457, Expected=19.430000
# Minute=38, Predicted=19.408668, Expected=19.430000
# Minute=39, Predicted=19.409805, Expected=19.430000
# Minute=40, Predicted=19.410507, Expected=19.430000
# Minute=41, Predicted=19.411400, Expected=20.420000
# Minute=42, Predicted=20.401927, Expected=20.420000
# Minute=43, Predicted=20.402587, Expected=20.420000
# Minute=44, Predicted=20.403026, Expected=20.420000
# Minute=45, Predicted=20.403504, Expected=20.420000
# Minute=46, Predicted=20.403880, Expected=20.420000
# Minute=47, Predicted=20.404231, Expected=20.420000
# Minute=48, Predicted=20.404531, Expected=19.940000
# Minute=49, Predicted=19.924791, Expected=19.940000
# Minute=50, Predicted=19.925033, Expected=19.940000
# Minute=51, Predicted=19.925231, Expected=19.940000
# Minute=52, Predicted=19.925414, Expected=19.940000
# Minute=53, Predicted=19.925569, Expected=19.940000
# Minute=54, Predicted=19.925712, Expected=19.940000
# Minute=55, Predicted=19.925836, Expected=20.090000
# Minute=56, Predicted=20.075947, Expected=20.090000
# Minute=57, Predicted=20.076036, Expected=20.090000
# Minute=58, Predicted=20.076125, Expected=20.090000
# Minute=59, Predicted=20.076202, Expected=20.090000
# Minute=60, Predicted=20.076266, Expected=20.090000
# Minute=61, Predicted=20.076325, Expected=20.090000
# Minute=62, Predicted=20.076378, Expected=19.700000
# Minute=63, Predicted=19.686424, Expected=19.700000
# Minute=64, Predicted=19.686466, Expected=19.700000
# Minute=65, Predicted=19.686499, Expected=19.700000
# Minute=66, Predicted=19.686530, Expected=19.700000
# Minute=67, Predicted=19.686557, Expected=19.700000
# Minute=68, Predicted=19.686586, Expected=19.700000
# Minute=69, Predicted=19.686604, Expected=20.440000
# Minute=70, Predicted=20.426625, Expected=20.440000
# Minute=71, Predicted=20.426639, Expected=20.440000
# Minute=72, Predicted=20.426655, Expected=20.440000
# Minute=73, Predicted=20.426670, Expected=20.440000
# Minute=74, Predicted=20.426681, Expected=20.440000
# Minute=75, Predicted=20.426693, Expected=20.440000
# Minute=76, Predicted=20.426701, Expected=21.460000
# Minute=77, Predicted=21.446711, Expected=21.460000
# Minute=78, Predicted=21.446718, Expected=21.460000
# Minute=79, Predicted=21.446725, Expected=21.460000
# Minute=80, Predicted=21.446728, Expected=21.460000
# Minute=81, Predicted=21.446733, Expected=21.460000
# Minute=82, Predicted=21.446738, Expected=21.460000
# Minute=83, Predicted=21.446742, Expected=21.460000
# Minute=84, Predicted=21.446744, Expected=21.460000
# Minute=85, Predicted=21.446748, Expected=21.460000
# Minute=86, Predicted=21.446751, Expected=21.460000
# Minute=87, Predicted=21.446752, Expected=21.460000
# Minute=88, Predicted=21.446754, Expected=21.460000
# Minute=89, Predicted=21.446756, Expected=21.460000
# Minute=90, Predicted=21.446759, Expected=20.230000
# Minute=91, Predicted=20.216761, Expected=20.230000
# Minute=92, Predicted=20.216760, Expected=20.230000
# Minute=93, Predicted=20.216764, Expected=20.230000
# Minute=94, Predicted=20.216763, Expected=20.230000
# Minute=95, Predicted=20.216764, Expected=20.230000
# Minute=96, Predicted=20.216765, Expected=20.230000
# Minute=97, Predicted=20.216766, Expected=20.000000
# Minute=98, Predicted=19.986767, Expected=20.000000
# Minute=99, Predicted=19.986767, Expected=20.000000
# Minute=100, Predicted=19.986769, Expected=20.000000
# Minute=101, Predicted=19.986767, Expected=20.000000
# Minute=102, Predicted=19.986768, Expected=20.000000
# Minute=103, Predicted=19.986770, Expected=20.000000
# Minute=104, Predicted=19.986769, Expected=19.170000
# Minute=105, Predicted=19.156769, Expected=19.170000
# Minute=106, Predicted=19.156769, Expected=19.170000
# Minute=107, Predicted=19.156770, Expected=19.170000
# Minute=108, Predicted=19.156771, Expected=19.170000
# Minute=109, Predicted=19.156771, Expected=19.170000
# Minute=110, Predicted=19.156770, Expected=19.170000
# Minute=111, Predicted=19.156769, Expected=19.770000
# Minute=112, Predicted=19.756770, Expected=19.770000
# Minute=113, Predicted=19.756771, Expected=19.770000
# Minute=114, Predicted=19.756770, Expected=19.770000
# Minute=115, Predicted=19.756771, Expected=19.770000
# Minute=116, Predicted=19.756771, Expected=19.770000
# Minute=117, Predicted=19.756771, Expected=19.770000
# Minute=118, Predicted=19.756771, Expected=19.220000
# Minute=119, Predicted=19.206771, Expected=19.220000
# Minute=120, Predicted=19.206770, Expected=19.220000
# Minute=121, Predicted=19.206770, Expected=19.220000
# Minute=122, Predicted=19.206771, Expected=19.220000
# Minute=123, Predicted=19.206771, Expected=19.220000
# Minute=124, Predicted=19.206771, Expected=19.220000
# Minute=125, Predicted=19.206773, Expected=19.630000
# Minute=126, Predicted=19.616771, Expected=19.630000
# Minute=127, Predicted=19.616772, Expected=19.630000
# Minute=128, Predicted=19.616770, Expected=19.630000
# Minute=129, Predicted=19.616770, Expected=19.630000
# Minute=130, Predicted=19.616774, Expected=19.630000
# Minute=131, Predicted=19.616771, Expected=19.630000
# Minute=132, Predicted=19.616771, Expected=19.540000
# Minute=133, Predicted=19.526771, Expected=19.540000
# Minute=134, Predicted=19.526772, Expected=19.540000
# Minute=135, Predicted=19.526771, Expected=19.540000
# Minute=136, Predicted=19.526771, Expected=19.540000
# Minute=137, Predicted=19.526771, Expected=19.540000
# Minute=138, Predicted=19.526771, Expected=19.540000
# Minute=139, Predicted=19.526771, Expected=19.840000
# Minute=140, Predicted=19.826773, Expected=19.840000
# Minute=141, Predicted=19.826771, Expected=19.840000
# Minute=142, Predicted=19.826771, Expected=19.840000
# Minute=143, Predicted=19.826771, Expected=19.840000
# Minute=144, Predicted=19.826770, Expected=19.840000
# Minute=145, Predicted=19.826773, Expected=19.840000
# Minute=146, Predicted=19.826771, Expected=19.840000
# Minute=147, Predicted=19.826771, Expected=19.000000
# Minute=148, Predicted=18.986771, Expected=19.000000
# Minute=149, Predicted=18.986772, Expected=19.000000
# Minute=150, Predicted=18.986771, Expected=19.000000
# Minute=151, Predicted=18.986771, Expected=19.000000
# Minute=152, Predicted=18.986771, Expected=19.000000
# Minute=153, Predicted=18.986771, Expected=19.000000
# Minute=154, Predicted=18.986772, Expected=18.730000
# Minute=155, Predicted=18.716771, Expected=18.730000
# Minute=156, Predicted=18.716772, Expected=18.730000
# Minute=157, Predicted=18.716771, Expected=18.730000
# Minute=158, Predicted=18.716771, Expected=18.730000
# Minute=159, Predicted=18.716771, Expected=18.730000
# Minute=160, Predicted=18.716772, Expected=18.730000
# Minute=161, Predicted=18.716771, Expected=19.080000
# Minute=162, Predicted=19.066772, Expected=19.080000
# Minute=163, Predicted=19.066771, Expected=19.080000
# Minute=164, Predicted=19.066771, Expected=19.080000
# Minute=165, Predicted=19.066771, Expected=19.080000
# Minute=166, Predicted=19.066772, Expected=19.080000
# Minute=167, Predicted=19.066771, Expected=19.080000
# Minute=168, Predicted=19.066772, Expected=19.510000
# Minute=169, Predicted=19.496771, Expected=19.510000
# Minute=170, Predicted=19.496772, Expected=19.510000
# Minute=171, Predicted=19.496771, Expected=19.510000
# Minute=172, Predicted=19.496771, Expected=19.510000
# Minute=173, Predicted=19.496771, Expected=19.510000
# Minute=174, Predicted=19.496772, Expected=19.510000
# Minute=175, Predicted=19.496772, Expected=18.970000
# Minute=176, Predicted=18.956772, Expected=18.970000
# Minute=177, Predicted=18.956771, Expected=18.970000
# Minute=178, Predicted=18.956771, Expected=18.970000
# Minute=179, Predicted=18.956772, Expected=18.970000
# Minute=180, Predicted=18.956771, Expected=18.970000
# Minute=181, Predicted=18.956772, Expected=18.970000
# Minute=182, Predicted=18.956771, Expected=18.530000
# Minute=183, Predicted=18.516771, Expected=18.530000
# Minute=184, Predicted=18.516771, Expected=18.530000
# Minute=185, Predicted=18.516772, Expected=18.530000
# Minute=186, Predicted=18.516771, Expected=18.530000
# Minute=187, Predicted=18.516772, Expected=18.530000
# Minute=188, Predicted=18.516771, Expected=18.530000
# Minute=189, Predicted=18.516771, Expected=18.190000
# Minute=190, Predicted=18.176770, Expected=18.190000
# Minute=191, Predicted=18.176773, Expected=18.190000
# Minute=192, Predicted=18.176773, Expected=18.190000
# Minute=193, Predicted=18.176772, Expected=18.190000
# Minute=194, Predicted=18.176772, Expected=18.190000
# Minute=195, Predicted=18.176771, Expected=18.190000
# Minute=196, Predicted=18.176772, Expected=17.690000
# Minute=197, Predicted=17.676771, Expected=17.690000
# Minute=198, Predicted=17.676772, Expected=17.690000
# Minute=199, Predicted=17.676771, Expected=17.690000
# Minute=200, Predicted=17.676771, Expected=17.690000
# Minute=201, Predicted=17.676770, Expected=17.690000
# Minute=202, Predicted=17.676773, Expected=17.690000
# Minute=203, Predicted=17.676771, Expected=17.810000
# Minute=204, Predicted=17.796773, Expected=17.810000
# Minute=205, Predicted=17.796771, Expected=17.810000
# Minute=206, Predicted=17.796771, Expected=17.810000
# Minute=207, Predicted=17.796771, Expected=17.810000
# Minute=208, Predicted=17.796772, Expected=17.810000
# Minute=209, Predicted=17.796772, Expected=17.810000
# Minute=210, Predicted=17.796772, Expected=17.700000
# Minute=211, Predicted=17.686771, Expected=17.700000
# Minute=212, Predicted=17.686771, Expected=17.700000
# Minute=213, Predicted=17.686772, Expected=17.700000
# Minute=214, Predicted=17.686771, Expected=17.700000
# Minute=215, Predicted=17.686771, Expected=17.700000
# Minute=216, Predicted=17.686770, Expected=17.700000
# Minute=217, Predicted=17.686773, Expected=18.430000
# Minute=218, Predicted=18.416773, Expected=18.430000
# Minute=219, Predicted=18.416770, Expected=18.430000
# Minute=220, Predicted=18.416772, Expected=18.430000
# Minute=221, Predicted=18.416770, Expected=18.430000
# Minute=222, Predicted=18.416771, Expected=18.430000
# Minute=223, Predicted=18.416772, Expected=18.430000
# Minute=224, Predicted=18.416772, Expected=21.410000
# Minute=225, Predicted=21.396773, Expected=21.410000
# Minute=226, Predicted=21.396772, Expected=21.410000
# Minute=227, Predicted=21.396771, Expected=21.410000
# Minute=228, Predicted=21.396772, Expected=21.410000
# Minute=229, Predicted=21.396771, Expected=21.410000
# Minute=230, Predicted=21.396771, Expected=21.410000
# Minute=231, Predicted=21.396771, Expected=20.690000
# Minute=232, Predicted=20.676771, Expected=20.690000
# Minute=233, Predicted=20.676772, Expected=20.690000
# Minute=234, Predicted=20.676771, Expected=20.690000
# Minute=235, Predicted=20.676771, Expected=20.690000
# Minute=236, Predicted=20.676771, Expected=20.690000
# Minute=237, Predicted=20.676771, Expected=20.690000
# Minute=238, Predicted=20.676772, Expected=20.980000
# Minute=239, Predicted=20.966770, Expected=20.980000
# Minute=240, Predicted=20.966771, Expected=20.980000
# Minute=241, Predicted=20.966771, Expected=20.980000
# Minute=242, Predicted=20.966773, Expected=20.980000
# Minute=243, Predicted=20.966771, Expected=20.980000
# Minute=244, Predicted=20.966771, Expected=20.980000
# Minute=245, Predicted=20.966772, Expected=20.880000
# Minute=246, Predicted=20.866771, Expected=20.880000
# Minute=247, Predicted=20.866772, Expected=20.880000
# Minute=248, Predicted=20.866771, Expected=20.880000
# Minute=249, Predicted=20.866771, Expected=20.880000
# Minute=250, Predicted=20.866771, Expected=20.880000
# Minute=251, Predicted=20.866771, Expected=20.880000
# Minute=252, Predicted=20.866771, Expected=21.190000
# Minute=253, Predicted=21.176770, Expected=21.190000
# Minute=254, Predicted=21.176773, Expected=21.190000
# Minute=255, Predicted=21.176773, Expected=21.190000
# Minute=256, Predicted=21.176771, Expected=21.190000
# Minute=257, Predicted=21.176773, Expected=21.190000
# Minute=258, Predicted=21.176771, Expected=21.190000
# Minute=259, Predicted=21.176772, Expected=20.500000
# Minute=260, Predicted=20.486773, Expected=20.500000
# Minute=261, Predicted=20.486771, Expected=20.500000
# Minute=262, Predicted=20.486773, Expected=20.500000
# Minute=263, Predicted=20.486771, Expected=20.500000
# Minute=264, Predicted=20.486771, Expected=20.500000
# Minute=265, Predicted=20.486771, Expected=20.500000
# Minute=266, Predicted=20.486771, Expected=20.420000
# Minute=267, Predicted=20.406771, Expected=20.420000
# Minute=268, Predicted=20.406771, Expected=20.420000
# Minute=269, Predicted=20.406771, Expected=20.420000
# Minute=270, Predicted=20.406773, Expected=20.420000
# Minute=271, Predicted=20.406771, Expected=20.420000
# Minute=272, Predicted=20.406771, Expected=20.420000
# Minute=273, Predicted=20.406771, Expected=20.080000
# Minute=274, Predicted=20.066771, Expected=20.080000
# Minute=275, Predicted=20.066771, Expected=20.080000
# Minute=276, Predicted=20.066771, Expected=20.080000
# Minute=277, Predicted=20.066770, Expected=20.080000
# Minute=278, Predicted=20.066771, Expected=20.080000
# Minute=279, Predicted=20.066771, Expected=20.080000
# Minute=280, Predicted=20.066773, Expected=18.450000
# Minute=281, Predicted=18.436771, Expected=18.450000
# Minute=282, Predicted=18.436771, Expected=18.450000
# Minute=283, Predicted=18.436771, Expected=18.450000
# Minute=284, Predicted=18.436771, Expected=18.450000
# Minute=285, Predicted=18.436773, Expected=18.450000
# Minute=286, Predicted=18.436772, Expected=18.450000
# Minute=287, Predicted=18.436771, Expected=18.450000
# Minute=288, Predicted=18.436772, Expected=19.910000
# Minute=289, Predicted=19.896772, Expected=19.910000
# Minute=290, Predicted=19.896771, Expected=19.910000
# Minute=291, Predicted=19.896772, Expected=19.910000
# Minute=292, Predicted=19.896771, Expected=19.910000
# Minute=293, Predicted=19.896771, Expected=19.910000
# Minute=294, Predicted=19.896770, Expected=19.960000
# Minute=295, Predicted=19.946773, Expected=19.960000
# Minute=296, Predicted=19.946773, Expected=19.960000
# Minute=297, Predicted=19.946770, Expected=19.960000
# Minute=298, Predicted=19.946772, Expected=19.960000
# Minute=299, Predicted=19.946771, Expected=19.960000
# Minute=300, Predicted=19.946771, Expected=19.960000
# Minute=301, Predicted=19.946771, Expected=19.960000
# Minute=302, Predicted=19.946772, Expected=20.370000
# Minute=303, Predicted=20.356771, Expected=20.370000
# Minute=304, Predicted=20.356771, Expected=20.370000
# Minute=305, Predicted=20.356771, Expected=20.370000
# Minute=306, Predicted=20.356771, Expected=20.370000
# Minute=307, Predicted=20.356771, Expected=20.370000
# Minute=308, Predicted=20.356772, Expected=20.370000
# Minute=309, Predicted=20.356771, Expected=20.340000
# Minute=310, Predicted=20.326772, Expected=20.340000
# Minute=311, Predicted=20.326771, Expected=20.340000
# Minute=312, Predicted=20.326771, Expected=20.340000
# Minute=313, Predicted=20.326770, Expected=20.340000
# Minute=314, Predicted=20.326773, Expected=20.340000
# Minute=315, Predicted=20.326773, Expected=20.340000
# Minute=316, Predicted=20.326772, Expected=20.500000
# Minute=317, Predicted=20.486771, Expected=20.500000
# Minute=318, Predicted=20.486771, Expected=20.500000
# Minute=319, Predicted=20.486771, Expected=20.500000
# Minute=320, Predicted=20.486770, Expected=20.500000
# Minute=321, Predicted=20.486773, Expected=20.500000
# Minute=322, Predicted=20.486773, Expected=20.500000
# Minute=323, Predicted=20.486771, Expected=21.240000
# Minute=324, Predicted=21.226773, Expected=21.240000
# Minute=325, Predicted=21.226771, Expected=21.240000
# Minute=326, Predicted=21.226771, Expected=21.240000
# Minute=327, Predicted=21.226771, Expected=21.240000
# Minute=328, Predicted=21.226772, Expected=21.240000
# Minute=329, Predicted=21.226771, Expected=21.240000
# Minute=330, Predicted=21.226771, Expected=21.050000
# Minute=331, Predicted=21.036770, Expected=21.050000
# Minute=332, Predicted=21.036773, Expected=21.050000
# Minute=333, Predicted=21.036773, Expected=21.050000
# Minute=334, Predicted=21.036771, Expected=21.050000
# Minute=335, Predicted=21.036771, Expected=21.050000
# Minute=336, Predicted=21.036772, Expected=21.050000
# Minute=337, Predicted=21.036770, Expected=21.510000
# Minute=338, Predicted=21.496771, Expected=21.510000
# Minute=339, Predicted=21.496771, Expected=21.510000
# Minute=340, Predicted=21.496771, Expected=21.510000
# Minute=341, Predicted=21.496771, Expected=21.510000
# Minute=342, Predicted=21.496770, Expected=21.510000
# Minute=343, Predicted=21.496773, Expected=21.510000
# Minute=344, Predicted=21.496773, Expected=22.510000
# Minute=345, Predicted=22.496771, Expected=22.510000
# Minute=346, Predicted=22.496772, Expected=22.510000
# Minute=347, Predicted=22.496771, Expected=22.510000
# Minute=348, Predicted=22.496771, Expected=22.510000
# Minute=349, Predicted=22.496771, Expected=22.510000
# Minute=350, Predicted=22.496772, Expected=22.510000
# Minute=351, Predicted=22.496771, Expected=22.580000
# Minute=352, Predicted=22.566772, Expected=22.580000
# Minute=353, Predicted=22.566771, Expected=22.580000
# Minute=354, Predicted=22.566771, Expected=22.580000
# Minute=355, Predicted=22.566771, Expected=22.580000
# Minute=356, Predicted=22.566772, Expected=22.580000
# Minute=357, Predicted=22.566771, Expected=22.580000
# Minute=358, Predicted=22.566772, Expected=22.580000
# Minute=359, Predicted=22.566771, Expected=22.890000
# Minute=360, Predicted=22.876771, Expected=22.890000
# Minute=361, Predicted=22.876770, Expected=22.890000
# Minute=362, Predicted=22.876773, Expected=22.890000
# Minute=363, Predicted=22.876773, Expected=22.890000
# Minute=364, Predicted=22.876771, Expected=22.890000
# Minute=365, Predicted=22.876771, Expected=22.890000
# Minute=366, Predicted=22.876771, Expected=23.220000
# Minute=367, Predicted=23.206773, Expected=23.220000
# Minute=368, Predicted=23.206771, Expected=23.220000
# Minute=369, Predicted=23.206771, Expected=23.220000
# Minute=370, Predicted=23.206770, Expected=23.220000
# Minute=371, Predicted=23.206773, Expected=23.220000
# Minute=372, Predicted=23.206771, Expected=23.220000
# Minute=373, Predicted=23.206772, Expected=23.240000
# Minute=374, Predicted=23.226770, Expected=23.240000
# Minute=375, Predicted=23.226771, Expected=23.240000
# Minute=376, Predicted=23.226771, Expected=23.240000
# Minute=377, Predicted=23.226771, Expected=23.240000
# Minute=378, Predicted=23.226771, Expected=23.240000
# Minute=379, Predicted=23.226771, Expected=23.240000
# Minute=380, Predicted=23.226773, Expected=23.710000
# Minute=381, Predicted=23.696771, Expected=23.710000
# Minute=382, Predicted=23.696772, Expected=23.710000
# Minute=383, Predicted=23.696771, Expected=23.710000
# Minute=384, Predicted=23.696771, Expected=23.710000
# Minute=385, Predicted=23.696770, Expected=23.710000
# Minute=386, Predicted=23.696773, Expected=23.710000
# Minute=387, Predicted=23.696771, Expected=23.730000
# Minute=388, Predicted=23.716773, Expected=23.730000
# Minute=389, Predicted=23.716771, Expected=23.730000
# Minute=390, Predicted=23.716771, Expected=23.730000
# Minute=391, Predicted=23.716771, Expected=23.730000
# Minute=392, Predicted=23.716772, Expected=23.730000
# Minute=393, Predicted=23.716771, Expected=23.730000
# Minute=394, Predicted=23.716772, Expected=23.790000
# Minute=395, Predicted=23.776771, Expected=23.790000
# Minute=396, Predicted=23.776771, Expected=23.790000
# Minute=397, Predicted=23.776771, Expected=23.790000
# Minute=398, Predicted=23.776772, Expected=23.790000
# Minute=399, Predicted=23.776771, Expected=23.790000
# Minute=400, Predicted=23.776772, Expected=23.790000
# Minute=401, Predicted=23.776771, Expected=22.870000
# Minute=402, Predicted=22.856771, Expected=22.870000
# Minute=403, Predicted=22.856771, Expected=22.870000
# Minute=404, Predicted=22.856771, Expected=22.870000
# Minute=405, Predicted=22.856771, Expected=22.870000
# Minute=406, Predicted=22.856771, Expected=22.870000
# Minute=407, Predicted=22.856772, Expected=22.870000
# Minute=408, Predicted=22.856771, Expected=22.380000
# Minute=409, Predicted=22.366772, Expected=22.380000
# Minute=410, Predicted=22.366771, Expected=22.380000
# Minute=411, Predicted=22.366771, Expected=22.380000
# Minute=412, Predicted=22.366771, Expected=22.380000
# Minute=413, Predicted=22.366772, Expected=22.380000
# Minute=414, Predicted=22.366771, Expected=22.380000
# Minute=415, Predicted=22.366772, Expected=22.380000
# Minute=416, Predicted=22.366771, Expected=22.810000
# Minute=417, Predicted=22.796771, Expected=22.810000
# Minute=418, Predicted=22.796771, Expected=22.810000
# Minute=419, Predicted=22.796772, Expected=22.810000
# Minute=420, Predicted=22.796771, Expected=22.810000
# Minute=421, Predicted=22.796772, Expected=22.810000
# Minute=422, Predicted=22.796771, Expected=22.810000
# Minute=423, Predicted=22.796772, Expected=22.500000
# Minute=424, Predicted=22.486771, Expected=22.500000
# Minute=425, Predicted=22.486771, Expected=22.500000
# Minute=426, Predicted=22.486771, Expected=22.500000
# Minute=427, Predicted=22.486772, Expected=22.500000
# Minute=428, Predicted=22.486771, Expected=22.500000
# Minute=429, Predicted=22.486772, Expected=22.500000
# Minute=430, Predicted=22.486771, Expected=23.040000
# Minute=431, Predicted=23.026771, Expected=23.040000
# Minute=432, Predicted=23.026771, Expected=23.040000
# Minute=433, Predicted=23.026771, Expected=23.040000
# Minute=434, Predicted=23.026771, Expected=23.040000
# Minute=435, Predicted=23.026772, Expected=23.040000
# Minute=436, Predicted=23.026770, Expected=23.040000
# Minute=437, Predicted=23.026771, Expected=22.110000
# Minute=438, Predicted=22.096771, Expected=22.110000
# Minute=439, Predicted=22.096773, Expected=22.110000
# Minute=440, Predicted=22.096773, Expected=22.110000
# Minute=441, Predicted=22.096770, Expected=22.110000
# Minute=442, Predicted=22.096771, Expected=22.110000
# Minute=443, Predicted=22.096771, Expected=22.110000
# Minute=444, Predicted=22.096774, Expected=21.960000
# Minute=445, Predicted=21.946771, Expected=21.960000
# Minute=446, Predicted=21.946771, Expected=21.960000
# Minute=447, Predicted=21.946771, Expected=21.960000
# Minute=448, Predicted=21.946773, Expected=21.960000
# Minute=449, Predicted=21.946771, Expected=21.960000
# Minute=450, Predicted=21.946771, Expected=21.960000
# Minute=451, Predicted=21.946771, Expected=22.500000
# Minute=452, Predicted=22.486772, Expected=22.500000
# Minute=453, Predicted=22.486771, Expected=22.500000
# Minute=454, Predicted=22.486772, Expected=22.500000
# Minute=455, Predicted=22.486771, Expected=22.500000
# Minute=456, Predicted=22.486771, Expected=22.500000
# Minute=457, Predicted=22.486771, Expected=22.500000
# Minute=458, Predicted=22.486772, Expected=21.680000
# Minute=459, Predicted=21.666771, Expected=21.680000
# Minute=460, Predicted=21.666772, Expected=21.680000
# Minute=461, Predicted=21.666771, Expected=21.680000
# Minute=462, Predicted=21.666771, Expected=21.680000
# Minute=463, Predicted=21.666771, Expected=21.680000
# Minute=464, Predicted=21.666772, Expected=21.680000
# Minute=465, Predicted=21.666771, Expected=21.860000
# Minute=466, Predicted=21.846772, Expected=21.860000
# Minute=467, Predicted=21.846771, Expected=21.860000
# Minute=468, Predicted=21.846771, Expected=21.860000
# Minute=469, Predicted=21.846771, Expected=21.860000
# Minute=470, Predicted=21.846772, Expected=21.860000
# Minute=471, Predicted=21.846771, Expected=21.860000
# Minute=472, Predicted=21.846772, Expected=21.130000
# Minute=473, Predicted=21.116771, Expected=21.130000
# Minute=474, Predicted=21.116771, Expected=21.130000
# Minute=475, Predicted=21.116771, Expected=21.130000
# Minute=476, Predicted=21.116772, Expected=21.130000
# Minute=477, Predicted=21.116771, Expected=21.130000
# Minute=478, Predicted=21.116772, Expected=21.130000
# Minute=479, Predicted=21.116771, Expected=21.530000
# Minute=480, Predicted=21.516771, Expected=21.530000
# Minute=481, Predicted=21.516771, Expected=21.530000
# Minute=482, Predicted=21.516772, Expected=21.530000
# Minute=483, Predicted=21.516771, Expected=21.530000
# Minute=484, Predicted=21.516772, Expected=21.530000
# Minute=485, Predicted=21.516771, Expected=21.530000
# Minute=486, Predicted=21.516771, Expected=21.000000
# Minute=487, Predicted=20.986771, Expected=21.000000
# Minute=488, Predicted=20.986772, Expected=21.000000
# Minute=489, Predicted=20.986771, Expected=21.000000
# Minute=490, Predicted=20.986772, Expected=21.000000
# Minute=491, Predicted=20.986771, Expected=21.000000
# Minute=492, Predicted=20.986771, Expected=21.000000
# Minute=493, Predicted=20.986771, Expected=23.140000
# Minute=494, Predicted=23.126772, Expected=23.140000
# Minute=495, Predicted=23.126771, Expected=23.140000
# Minute=496, Predicted=23.126772, Expected=23.140000
# Minute=497, Predicted=23.126771, Expected=23.140000
# Minute=498, Predicted=23.126771, Expected=23.140000
# Minute=499, Predicted=23.126771, Expected=23.140000
# Minute=500, Predicted=23.126772, Expected=22.600000
# Minute=501, Predicted=22.586771, Expected=22.600000
# Minute=502, Predicted=22.586772, Expected=22.600000
# Minute=503, Predicted=22.586771, Expected=22.600000
# Minute=504, Predicted=22.586771, Expected=22.600000
# Minute=505, Predicted=22.586771, Expected=22.600000
# Minute=506, Predicted=22.586772, Expected=22.600000
# Minute=507, Predicted=22.586771, Expected=22.750000
# Minute=508, Predicted=22.736772, Expected=22.750000
# Minute=509, Predicted=22.736771, Expected=22.750000
# Minute=510, Predicted=22.736771, Expected=22.750000
# Minute=511, Predicted=22.736771, Expected=22.750000
# Minute=512, Predicted=22.736772, Expected=22.750000
# Minute=513, Predicted=22.736771, Expected=22.750000
# Minute=514, Predicted=22.736772, Expected=21.720000
# Minute=515, Predicted=21.706771, Expected=21.720000
# Minute=516, Predicted=21.706771, Expected=21.720000
# Minute=517, Predicted=21.706771, Expected=21.720000
# Minute=518, Predicted=21.706772, Expected=21.720000
# Minute=519, Predicted=21.706771, Expected=21.720000
# Minute=520, Predicted=21.706772, Expected=21.720000
# Minute=521, Predicted=21.706771, Expected=21.350000
# Minute=522, Predicted=21.336771, Expected=21.350000
# Minute=523, Predicted=21.336771, Expected=21.350000
# Minute=524, Predicted=21.336772, Expected=21.350000
# Minute=525, Predicted=21.336771, Expected=21.350000
# Minute=526, Predicted=21.336772, Expected=21.350000
# Minute=527, Predicted=21.336771, Expected=21.350000
# Minute=528, Predicted=21.336771, Expected=21.400000
# Minute=529, Predicted=21.386771, Expected=21.400000
# Minute=530, Predicted=21.386772, Expected=21.400000
# Minute=531, Predicted=21.386771, Expected=21.400000
# Minute=532, Predicted=21.386772, Expected=21.400000
# Minute=533, Predicted=21.386771, Expected=21.400000
# Minute=534, Predicted=21.386771, Expected=21.400000
# Minute=535, Predicted=21.386771, Expected=21.490000
# Minute=536, Predicted=21.476772, Expected=21.490000
# Minute=537, Predicted=21.476771, Expected=21.490000
# Minute=538, Predicted=21.476772, Expected=21.490000
# Minute=539, Predicted=21.476771, Expected=21.490000
# Minute=540, Predicted=21.476771, Expected=21.490000
# Minute=541, Predicted=21.476771, Expected=21.490000
# Minute=542, Predicted=21.476772, Expected=21.320000
# Minute=543, Predicted=21.306771, Expected=21.320000
# Minute=544, Predicted=21.306772, Expected=21.320000
# Minute=545, Predicted=21.306771, Expected=21.320000
# Minute=546, Predicted=21.306771, Expected=21.320000
# Minute=547, Predicted=21.306771, Expected=21.320000
# Minute=548, Predicted=21.306772, Expected=21.320000
# Minute=549, Predicted=21.306771, Expected=21.620000
# Minute=550, Predicted=21.606772, Expected=21.620000
# Minute=551, Predicted=21.606771, Expected=21.620000
# Minute=552, Predicted=21.606771, Expected=21.620000
# Minute=553, Predicted=21.606771, Expected=21.620000
# Minute=554, Predicted=21.606772, Expected=21.620000
# Minute=555, Predicted=21.606771, Expected=21.620000
# Minute=556, Predicted=21.606772, Expected=23.050000
# Minute=557, Predicted=23.036771, Expected=23.050000
# Minute=558, Predicted=23.036771, Expected=23.050000
# Minute=559, Predicted=23.036771, Expected=23.050000
# Minute=560, Predicted=23.036772, Expected=23.050000
# Minute=561, Predicted=23.036771, Expected=23.050000
# Minute=562, Predicted=23.036772, Expected=23.050000
# Minute=563, Predicted=23.036771, Expected=21.960000
# Minute=564, Predicted=21.946771, Expected=21.960000
# Minute=565, Predicted=21.946771, Expected=21.960000
# Minute=566, Predicted=21.946772, Expected=21.960000
# Minute=567, Predicted=21.946771, Expected=21.960000
# Minute=568, Predicted=21.946772, Expected=21.960000
# Minute=569, Predicted=21.946771, Expected=21.960000
# Minute=570, Predicted=21.946771, Expected=21.480000
# Minute=571, Predicted=21.466771, Expected=21.480000
# Minute=572, Predicted=21.466772, Expected=21.480000
# Minute=573, Predicted=21.466771, Expected=21.480000
# Minute=574, Predicted=21.466772, Expected=21.480000
# Minute=575, Predicted=21.466771, Expected=21.480000
# Minute=576, Predicted=21.466771, Expected=21.480000
# Minute=577, Predicted=21.466771, Expected=21.310000
# Minute=578, Predicted=21.296772, Expected=21.310000
# Minute=579, Predicted=21.296771, Expected=21.310000
# Minute=580, Predicted=21.296772, Expected=21.310000
# Minute=581, Predicted=21.296771, Expected=21.310000
# Minute=582, Predicted=21.296771, Expected=21.310000
# Minute=583, Predicted=21.296771, Expected=21.310000
# Minute=584, Predicted=21.296772, Expected=21.460000
# Minute=585, Predicted=21.446771, Expected=21.460000
# Minute=586, Predicted=21.446772, Expected=21.460000
# Minute=587, Predicted=21.446771, Expected=21.460000
# Minute=588, Predicted=21.446771, Expected=21.460000
# Minute=589, Predicted=21.446771, Expected=21.460000
# Minute=590, Predicted=21.446772, Expected=21.460000
# Minute=591, Predicted=21.446771, Expected=21.460000
# Minute=592, Predicted=21.446772, Expected=21.640000
# Minute=593, Predicted=21.626771, Expected=21.640000
# Minute=594, Predicted=21.626771, Expected=21.640000
# Minute=595, Predicted=21.626771, Expected=21.640000
# Minute=596, Predicted=21.626772, Expected=21.640000
# Minute=597, Predicted=21.626771, Expected=21.640000
# Minute=598, Predicted=21.626772, Expected=21.640000
# Minute=599, Predicted=21.626771, Expected=21.260000
# Minute=600, Predicted=21.246771, Expected=21.260000
# Minute=601, Predicted=21.246771, Expected=21.260000
# Minute=602, Predicted=21.246772, Expected=21.260000
# Minute=603, Predicted=21.246771, Expected=21.260000
# Minute=604, Predicted=21.246772, Expected=21.260000
# Minute=605, Predicted=21.246771, Expected=21.260000
# Minute=606, Predicted=21.246771, Expected=21.680000
# Minute=607, Predicted=21.666771, Expected=21.680000
# Minute=608, Predicted=21.666772, Expected=21.680000
# Minute=609, Predicted=21.666771, Expected=21.680000
# Minute=610, Predicted=21.666772, Expected=21.680000
# Minute=611, Predicted=21.666771, Expected=21.680000
# Minute=612, Predicted=21.666771, Expected=21.680000
# Minute=613, Predicted=21.666771, Expected=19.250000
# Minute=614, Predicted=19.236772, Expected=19.250000
# Minute=615, Predicted=19.236771, Expected=19.250000
# Minute=616, Predicted=19.236772, Expected=19.250000
# Minute=617, Predicted=19.236771, Expected=19.250000
# Minute=618, Predicted=19.236771, Expected=19.250000
# Minute=619, Predicted=19.236771, Expected=19.250000
# Minute=620, Predicted=19.236772, Expected=19.060000
# Minute=621, Predicted=19.046771, Expected=19.060000
# Minute=622, Predicted=19.046772, Expected=19.060000
# Minute=623, Predicted=19.046771, Expected=19.060000
# Minute=624, Predicted=19.046771, Expected=19.060000
# Minute=625, Predicted=19.046771, Expected=19.060000
# Minute=626, Predicted=19.046772, Expected=19.060000
# Minute=627, Predicted=19.046771, Expected=19.250000
# Minute=628, Predicted=19.236772, Expected=19.250000
# Minute=629, Predicted=19.236771, Expected=19.250000
# Minute=630, Predicted=19.236771, Expected=19.250000
# Minute=631, Predicted=19.236771, Expected=19.250000
# Minute=632, Predicted=19.236772, Expected=19.250000
# Minute=633, Predicted=19.236771, Expected=19.250000
# Minute=634, Predicted=19.236772, Expected=18.700000
# Minute=635, Predicted=18.686771, Expected=18.700000
# Minute=636, Predicted=18.686771, Expected=18.700000
# Minute=637, Predicted=18.686771, Expected=18.700000
# Minute=638, Predicted=18.686772, Expected=18.700000
# Minute=639, Predicted=18.686771, Expected=18.700000
# Minute=640, Predicted=18.686772, Expected=18.700000
# Minute=641, Predicted=18.686771, Expected=19.090000
# Minute=642, Predicted=19.076771, Expected=19.090000
# Minute=643, Predicted=19.076771, Expected=19.090000
# Minute=644, Predicted=19.076772, Expected=19.090000
# Minute=645, Predicted=19.076771, Expected=19.090000
# Minute=646, Predicted=19.076772, Expected=19.090000
# Minute=647, Predicted=19.076771, Expected=19.090000
# Minute=648, Predicted=19.076771, Expected=18.500000
# Minute=649, Predicted=18.486771, Expected=18.500000
# Minute=650, Predicted=18.486772, Expected=18.500000
# Minute=651, Predicted=18.486771, Expected=18.500000
# Minute=652, Predicted=18.486772, Expected=18.500000
# Minute=653, Predicted=18.486771, Expected=18.500000
# Minute=654, Predicted=18.486771, Expected=18.500000
# Minute=655, Predicted=18.486771, Expected=18.740000
# Minute=656, Predicted=18.726772, Expected=18.740000
# Minute=657, Predicted=18.726771, Expected=18.740000
# Minute=658, Predicted=18.726772, Expected=18.740000
# Minute=659, Predicted=18.726771, Expected=18.740000
# Minute=660, Predicted=18.726771, Expected=18.740000
# Minute=661, Predicted=18.726771, Expected=18.740000
# Minute=662, Predicted=18.726772, Expected=18.130000
# Minute=663, Predicted=18.116771, Expected=18.130000
# Minute=664, Predicted=18.116772, Expected=18.130000
# Minute=665, Predicted=18.116771, Expected=18.130000
# Minute=666, Predicted=18.116771, Expected=18.130000
# Minute=667, Predicted=18.116771, Expected=18.130000
# Minute=668, Predicted=18.116772, Expected=18.130000
# Minute=669, Predicted=18.116771, Expected=18.570000
# Minute=670, Predicted=18.556772, Expected=18.570000
# Minute=671, Predicted=18.556771, Expected=18.570000
# Minute=672, Predicted=18.556771, Expected=18.570000
# Minute=673, Predicted=18.556771, Expected=18.570000
# Minute=674, Predicted=18.556772, Expected=18.570000
# Minute=675, Predicted=18.556771, Expected=18.570000
# Minute=676, Predicted=18.556772, Expected=19.310000
# Minute=677, Predicted=19.296771, Expected=19.310000
# Minute=678, Predicted=19.296771, Expected=19.310000
# Minute=679, Predicted=19.296771, Expected=19.310000
# Minute=680, Predicted=19.296772, Expected=19.310000
# Minute=681, Predicted=19.296771, Expected=19.310000
# Minute=682, Predicted=19.296772, Expected=19.310000
# Minute=683, Predicted=19.296771, Expected=17.680000
# Minute=684, Predicted=17.666771, Expected=17.680000
# Minute=685, Predicted=17.666771, Expected=17.680000
# Minute=686, Predicted=17.666772, Expected=17.680000
# Minute=687, Predicted=17.666771, Expected=17.680000
# Minute=688, Predicted=17.666772, Expected=17.680000
# Minute=689, Predicted=17.666771, Expected=17.680000
# Minute=690, Predicted=17.666771, Expected=17.400000
# Minute=691, Predicted=17.386771, Expected=17.400000
# Minute=692, Predicted=17.386772, Expected=17.400000
# Minute=693, Predicted=17.386771, Expected=17.400000
# Minute=694, Predicted=17.386772, Expected=17.400000
# Minute=695, Predicted=17.386771, Expected=17.400000
# Minute=696, Predicted=17.386771, Expected=17.400000
# Minute=697, Predicted=17.386771, Expected=17.830000
# Minute=698, Predicted=17.816772, Expected=17.830000
# Minute=699, Predicted=17.816771, Expected=17.830000
# Minute=700, Predicted=17.816772, Expected=17.830000
# Minute=701, Predicted=17.816771, Expected=17.830000
# Minute=702, Predicted=17.816771, Expected=17.830000
# Minute=703, Predicted=17.816771, Expected=17.830000
# Minute=704, Predicted=17.816772, Expected=17.830000
# Minute=705, Predicted=17.816771, Expected=18.810000
# Minute=706, Predicted=18.796772, Expected=18.810000
# Minute=707, Predicted=18.796771, Expected=18.810000
# Minute=708, Predicted=18.796771, Expected=18.810000
# Minute=709, Predicted=18.796771, Expected=18.810000
# Minute=710, Predicted=18.796772, Expected=18.810000
# Minute=711, Predicted=18.796771, Expected=18.810000
# Minute=712, Predicted=18.796772, Expected=18.150000
# Minute=713, Predicted=18.136771, Expected=18.150000
# Minute=714, Predicted=18.136771, Expected=18.150000
# Minute=715, Predicted=18.136771, Expected=18.150000
# Minute=716, Predicted=18.136772, Expected=18.150000
# Minute=717, Predicted=18.136771, Expected=18.150000
# Minute=718, Predicted=18.136772, Expected=18.150000
# Minute=719, Predicted=18.136771, Expected=18.200000
# Minute=720, Predicted=18.186771, Expected=18.200000
# Minute=721, Predicted=18.186771, Expected=18.200000
# Minute=722, Predicted=18.186772, Expected=18.200000
# Minute=723, Predicted=18.186771, Expected=18.200000
# Minute=724, Predicted=18.186772, Expected=18.200000
# Minute=725, Predicted=18.186771, Expected=18.200000
# Minute=726, Predicted=18.186771, Expected=16.920000
# Minute=727, Predicted=16.906771, Expected=16.920000
# Minute=728, Predicted=16.906772, Expected=16.920000
# Minute=729, Predicted=16.906771, Expected=16.920000
# Minute=730, Predicted=16.906772, Expected=16.920000
# Minute=731, Predicted=16.906771, Expected=16.920000
# Minute=732, Predicted=16.906771, Expected=16.920000
# Minute=733, Predicted=16.906771, Expected=16.530000
# Minute=734, Predicted=16.516772, Expected=16.530000
# Minute=735, Predicted=16.516771, Expected=16.530000
# Minute=736, Predicted=16.516772, Expected=16.530000
# Minute=737, Predicted=16.516771, Expected=16.530000
# Minute=738, Predicted=16.516771, Expected=16.530000
# Minute=739, Predicted=16.516771, Expected=16.530000
# Minute=740, Predicted=16.516772, Expected=16.560000
# Minute=741, Predicted=16.546771, Expected=16.560000
# Minute=742, Predicted=16.546772, Expected=16.560000
# Minute=743, Predicted=16.546771, Expected=16.560000
# Minute=744, Predicted=16.546771, Expected=16.560000
# Minute=745, Predicted=16.546771, Expected=16.560000
# Minute=746, Predicted=16.546772, Expected=16.560000
# Minute=747, Predicted=16.546771, Expected=16.560000
# Minute=748, Predicted=16.546772, Expected=16.700000
# Minute=749, Predicted=16.686771, Expected=16.700000
# Minute=750, Predicted=16.686771, Expected=16.700000
# Minute=751, Predicted=16.686771, Expected=16.700000
# Minute=752, Predicted=16.686772, Expected=16.700000
# Minute=753, Predicted=16.686771, Expected=16.700000
# Minute=754, Predicted=16.686772, Expected=16.850000
# Minute=755, Predicted=16.836771, Expected=16.850000
# Minute=756, Predicted=16.836771, Expected=16.850000
# Minute=757, Predicted=16.836771, Expected=16.850000
# Minute=758, Predicted=16.836772, Expected=16.850000
# Minute=759, Predicted=16.836771, Expected=16.850000
# Minute=760, Predicted=16.836772, Expected=16.850000
# Minute=761, Predicted=16.836771, Expected=15.790000
# Minute=762, Predicted=15.776771, Expected=15.790000
# Minute=763, Predicted=15.776771, Expected=15.790000
# Minute=764, Predicted=15.776772, Expected=15.790000
# Minute=765, Predicted=15.776771, Expected=15.790000
# Minute=766, Predicted=15.776772, Expected=15.790000
# Minute=767, Predicted=15.776771, Expected=15.790000
# Minute=768, Predicted=15.776771, Expected=15.570000
# Minute=769, Predicted=15.556771, Expected=15.570000
# Minute=770, Predicted=15.556772, Expected=15.570000
# Minute=771, Predicted=15.556771, Expected=15.570000
# Minute=772, Predicted=15.556772, Expected=15.570000
# Minute=773, Predicted=15.556771, Expected=15.570000
# Minute=774, Predicted=15.556771, Expected=15.570000
# Minute=775, Predicted=15.556771, Expected=16.560000
# Minute=776, Predicted=16.546772, Expected=16.560000
# Minute=777, Predicted=16.546771, Expected=16.560000
# Minute=778, Predicted=16.546772, Expected=16.560000
# Minute=779, Predicted=16.546771, Expected=16.560000
# Minute=780, Predicted=16.546771, Expected=16.560000
# Minute=781, Predicted=16.546771, Expected=16.560000
# Minute=782, Predicted=16.546772, Expected=16.560000
# Minute=783, Predicted=16.546771, Expected=16.720000
# Minute=784, Predicted=16.706772, Expected=16.720000
# Minute=785, Predicted=16.706771, Expected=16.720000
# Minute=786, Predicted=16.706771, Expected=16.720000
# Minute=787, Predicted=16.706771, Expected=16.720000
# Minute=788, Predicted=16.706772, Expected=16.720000
# Minute=789, Predicted=16.706771, Expected=16.720000
# Minute=790, Predicted=16.706772, Expected=18.440000
# Minute=791, Predicted=18.426771, Expected=18.440000
# Minute=792, Predicted=18.426771, Expected=18.440000
# Minute=793, Predicted=18.426771, Expected=18.440000
# Minute=794, Predicted=18.426772, Expected=18.440000
# Minute=795, Predicted=18.426771, Expected=18.440000
# Minute=796, Predicted=18.426772, Expected=18.440000
# Minute=797, Predicted=18.426771, Expected=18.440000
# Minute=798, Predicted=18.426771, Expected=18.350000
# Minute=799, Predicted=18.336771, Expected=18.350000
# Minute=800, Predicted=18.336772, Expected=18.350000
# Minute=801, Predicted=18.336771, Expected=18.350000
# Minute=802, Predicted=18.336772, Expected=18.350000
# Minute=803, Predicted=18.336771, Expected=18.350000
# Minute=804, Predicted=18.336771, Expected=18.350000
# Minute=805, Predicted=18.336771, Expected=18.050000
# Minute=806, Predicted=18.036772, Expected=18.050000
# Minute=807, Predicted=18.036771, Expected=18.050000
# Minute=808, Predicted=18.036772, Expected=18.050000
# Minute=809, Predicted=18.036771, Expected=18.050000
# Minute=810, Predicted=18.036771, Expected=18.050000
# Minute=811, Predicted=18.036771, Expected=18.050000
# Minute=812, Predicted=18.036772, Expected=18.610000
# Minute=813, Predicted=18.596771, Expected=18.610000
# Minute=814, Predicted=18.596772, Expected=18.610000
# Minute=815, Predicted=18.596771, Expected=18.610000
# Minute=816, Predicted=18.596771, Expected=18.610000
# Minute=817, Predicted=18.596771, Expected=18.610000
# Minute=818, Predicted=18.596772, Expected=18.610000
# Minute=819, Predicted=18.596771, Expected=19.310000
# Minute=820, Predicted=19.296772, Expected=19.310000
# Minute=821, Predicted=19.296771, Expected=19.310000
# Minute=822, Predicted=19.296771, Expected=19.310000
# Minute=823, Predicted=19.296771, Expected=19.310000
# Minute=824, Predicted=19.296772, Expected=19.310000
# Minute=825, Predicted=19.296771, Expected=19.310000
# Minute=826, Predicted=19.296772, Expected=20.180000
# Minute=827, Predicted=20.166771, Expected=20.180000
# Minute=828, Predicted=20.166771, Expected=20.180000
# Minute=829, Predicted=20.166771, Expected=20.180000
# Minute=830, Predicted=20.166772, Expected=20.180000
# Minute=831, Predicted=20.166771, Expected=20.180000
# Minute=832, Predicted=20.166772, Expected=20.180000
# Minute=833, Predicted=20.166771, Expected=19.580000
# Minute=834, Predicted=19.566771, Expected=19.580000
# Minute=835, Predicted=19.566771, Expected=19.580000
# Minute=836, Predicted=19.566772, Expected=19.580000
# Minute=837, Predicted=19.566771, Expected=19.580000
# Minute=838, Predicted=19.566772, Expected=19.580000
# Minute=839, Predicted=19.566771, Expected=19.580000
# Minute=840, Predicted=19.566771, Expected=19.190000
# Minute=841, Predicted=19.176771, Expected=19.190000
# Minute=842, Predicted=19.176772, Expected=19.190000
# Minute=843, Predicted=19.176771, Expected=19.190000
# Minute=844, Predicted=19.176772, Expected=19.190000
# Minute=845, Predicted=19.176771, Expected=19.190000
# Minute=846, Predicted=19.176771, Expected=19.190000
# Minute=847, Predicted=19.176771, Expected=19.410000
# Minute=848, Predicted=19.396772, Expected=19.410000
# Minute=849, Predicted=19.396771, Expected=19.410000
# Minute=850, Predicted=19.396772, Expected=19.410000
# Minute=851, Predicted=19.396771, Expected=19.410000
# Minute=852, Predicted=19.396771, Expected=19.410000
# Minute=853, Predicted=19.396771, Expected=19.410000
# Minute=854, Predicted=19.396772, Expected=19.320000
# Minute=855, Predicted=19.306771, Expected=19.320000
# Minute=856, Predicted=19.306772, Expected=19.320000
# Minute=857, Predicted=19.306771, Expected=19.320000
# Minute=858, Predicted=19.306771, Expected=19.320000
# Minute=859, Predicted=19.306771, Expected=19.320000
# Minute=860, Predicted=19.306772, Expected=19.320000
# Minute=861, Predicted=19.306771, Expected=19.570000
# Minute=862, Predicted=19.556772, Expected=19.570000
# Minute=863, Predicted=19.556771, Expected=19.570000
# Minute=864, Predicted=19.556771, Expected=19.570000
# Minute=865, Predicted=19.556771, Expected=19.570000
# Minute=866, Predicted=19.556772, Expected=19.570000
# Minute=867, Predicted=19.556771, Expected=19.570000
# Minute=868, Predicted=19.556772, Expected=19.620000
# Minute=869, Predicted=19.606771, Expected=19.620000
# Minute=870, Predicted=19.606771, Expected=19.620000
# Minute=871, Predicted=19.606771, Expected=19.620000
# Minute=872, Predicted=19.606772, Expected=19.620000
# Minute=873, Predicted=19.606771, Expected=19.620000
# Minute=874, Predicted=19.606772, Expected=19.620000
# Minute=875, Predicted=19.606771, Expected=18.850000
# Minute=876, Predicted=18.836771, Expected=18.850000
# Minute=877, Predicted=18.836771, Expected=18.850000
# Minute=878, Predicted=18.836772, Expected=18.850000
# Minute=879, Predicted=18.836771, Expected=18.850000
# Minute=880, Predicted=18.836772, Expected=18.850000
# Minute=881, Predicted=18.836771, Expected=19.940000
# Minute=882, Predicted=19.926771, Expected=19.940000
# Minute=883, Predicted=19.926771, Expected=19.940000
# Minute=884, Predicted=19.926772, Expected=19.940000
# Minute=885, Predicted=19.926771, Expected=19.940000
# Minute=886, Predicted=19.926772, Expected=19.940000
# Minute=887, Predicted=19.926771, Expected=19.940000
# Minute=888, Predicted=19.926771, Expected=19.980000
# Minute=889, Predicted=19.966771, Expected=19.980000
# Minute=890, Predicted=19.966772, Expected=19.980000
# Minute=891, Predicted=19.966771, Expected=19.980000
# Minute=892, Predicted=19.966772, Expected=19.980000
# Minute=893, Predicted=19.966771, Expected=19.980000
# Minute=894, Predicted=19.966771, Expected=19.980000
# Minute=895, Predicted=19.966771, Expected=19.570000
# Minute=896, Predicted=19.556772, Expected=19.570000
# Minute=897, Predicted=19.556771, Expected=19.570000
# Minute=898, Predicted=19.556772, Expected=19.570000
# Minute=899, Predicted=19.556771, Expected=19.570000
# Minute=900, Predicted=19.556771, Expected=19.570000
# Minute=901, Predicted=19.556771, Expected=19.570000
# Minute=902, Predicted=19.556772, Expected=22.330000
# Minute=903, Predicted=22.316771, Expected=22.330000
# Minute=904, Predicted=22.316772, Expected=22.330000
# Minute=905, Predicted=22.316771, Expected=22.330000
# Minute=906, Predicted=22.316771, Expected=22.330000
# Minute=907, Predicted=22.316771, Expected=22.330000
# Minute=908, Predicted=22.316772, Expected=22.330000
# Minute=909, Predicted=22.316771, Expected=21.660000
# Minute=910, Predicted=21.646772, Expected=21.660000
# Minute=911, Predicted=21.646771, Expected=21.660000
# Minute=912, Predicted=21.646771, Expected=21.660000
# Minute=913, Predicted=21.646771, Expected=21.660000
# Minute=914, Predicted=21.646772, Expected=21.660000
# Minute=915, Predicted=21.646771, Expected=21.660000
# Minute=916, Predicted=21.646772, Expected=22.580000
# Minute=917, Predicted=22.566771, Expected=22.580000
# Minute=918, Predicted=22.566771, Expected=22.580000
# Minute=919, Predicted=22.566771, Expected=22.580000
# Minute=920, Predicted=22.566772, Expected=22.580000
# Minute=921, Predicted=22.566771, Expected=22.580000
# Minute=922, Predicted=22.566772, Expected=22.580000
# Minute=923, Predicted=22.566771, Expected=21.910000
# Minute=924, Predicted=21.896771, Expected=21.910000
# Minute=925, Predicted=21.896771, Expected=21.910000
# ...
# Minute=42906, Predicted=19.476771, Expected=19.490000
# Minute=42907, Predicted=19.476771, Expected=19.490000
# Minute=42908, Predicted=19.476772, Expected=19.490000
# Minute=42909, Predicted=19.476771, Expected=19.000000
# Minute=42910, Predicted=18.986772, Expected=19.000000
# Minute=42911, Predicted=18.986771, Expected=19.000000
# Minute=42912, Predicted=18.986771, Expected=19.000000
# Minute=42913, Predicted=18.986771, Expected=19.000000
# Minute=42914, Predicted=18.986772, Expected=19.000000
# Minute=42915, Predicted=18.986771, Expected=19.000000
# Minute=42916, Predicted=18.986772, Expected=19.000000
# Minute=42917, Predicted=18.986771, Expected=19.000000
# Minute=42918, Predicted=18.986771, Expected=19.000000
# Minute=42919, Predicted=18.986771, Expected=19.470000
# Minute=42920, Predicted=19.456772, Expected=19.470000
# Minute=42921, Predicted=19.456771, Expected=19.470000
# Minute=42922, Predicted=19.456772, Expected=19.470000
# Minute=42923, Predicted=19.456771, Expected=19.470000
# Minute=42924, Predicted=19.456771, Expected=19.470000
# Minute=42925, Predicted=19.456771, Expected=19.470000
# Minute=42926, Predicted=19.456772, Expected=19.070000
# Minute=42927, Predicted=19.056771, Expected=19.070000
# Minute=42928, Predicted=19.056772, Expected=19.070000
# Minute=42929, Predicted=19.056771, Expected=19.070000
# Minute=42930, Predicted=19.056771, Expected=19.070000
# Minute=42931, Predicted=19.056771, Expected=19.070000
# Minute=42932, Predicted=19.056772, Expected=18.650000
# Minute=42933, Predicted=18.636771, Expected=18.650000
# Minute=42934, Predicted=18.636772, Expected=18.650000
# Minute=42935, Predicted=18.636771, Expected=18.650000
# Minute=42936, Predicted=18.636771, Expected=18.650000
# Minute=42937, Predicted=18.636771, Expected=18.650000
# Minute=42938, Predicted=18.636772, Expected=18.650000
# Minute=42939, Predicted=18.636771, Expected=18.950000
# Minute=42940, Predicted=18.936772, Expected=18.950000
# Minute=42941, Predicted=18.936771, Expected=18.950000
# Minute=42942, Predicted=18.936771, Expected=18.950000
# Minute=42943, Predicted=18.936771, Expected=18.950000
# Minute=42944, Predicted=18.936772, Expected=18.950000
# Minute=42945, Predicted=18.936771, Expected=18.950000
# Minute=42946, Predicted=18.936772, Expected=19.370000
# Minute=42947, Predicted=19.356771, Expected=19.370000
# Minute=42948, Predicted=19.356771, Expected=19.370000
# Minute=42949, Predicted=19.356771, Expected=19.370000
# Minute=42950, Predicted=19.356772, Expected=19.370000
# Minute=42951, Predicted=19.356771, Expected=19.370000
# Minute=42952, Predicted=19.356772, Expected=18.740000
# Minute=42953, Predicted=18.726771, Expected=18.740000
# Minute=42954, Predicted=18.726771, Expected=18.740000
# Minute=42955, Predicted=18.726771, Expected=18.740000
# Minute=42956, Predicted=18.726772, Expected=18.740000
# Minute=42957, Predicted=18.726771, Expected=18.740000
# Minute=42958, Predicted=18.726772, Expected=18.740000
# Minute=42959, Predicted=18.726771, Expected=19.200000
# Minute=42960, Predicted=19.186771, Expected=19.200000
# Minute=42961, Predicted=19.186771, Expected=19.200000
# Minute=42962, Predicted=19.186772, Expected=19.200000
# Minute=42963, Predicted=19.186771, Expected=19.200000
# Minute=42964, Predicted=19.186772, Expected=19.200000
# Minute=42965, Predicted=19.186771, Expected=19.200000
# Minute=42966, Predicted=19.186771, Expected=18.580000
# Minute=42967, Predicted=18.566771, Expected=18.580000
# Minute=42968, Predicted=18.566772, Expected=18.580000
# Minute=42969, Predicted=18.566771, Expected=18.580000
# Minute=42970, Predicted=18.566772, Expected=18.580000
# Minute=42971, Predicted=18.566771, Expected=18.580000
# Minute=42972, Predicted=18.566771, Expected=18.810000
# Minute=42973, Predicted=18.796771, Expected=18.810000
# Minute=42974, Predicted=18.796772, Expected=18.810000
# Minute=42975, Predicted=18.796771, Expected=18.810000
# Minute=42976, Predicted=18.796772, Expected=18.810000
# Minute=42977, Predicted=18.796771, Expected=18.810000
# Minute=42978, Predicted=18.796771, Expected=18.810000
# Minute=42979, Predicted=18.796771, Expected=18.810000
# Minute=42980, Predicted=18.796772, Expected=18.810000
# Minute=42981, Predicted=18.796771, Expected=18.810000
# Minute=42982, Predicted=18.796772, Expected=18.810000
# Minute=42983, Predicted=18.796771, Expected=18.810000
# Minute=42984, Predicted=18.796771, Expected=18.810000
# Minute=42985, Predicted=18.796771, Expected=18.810000
# Minute=42986, Predicted=18.796772, Expected=19.090000
# Minute=42987, Predicted=19.076771, Expected=19.090000
# Minute=42988, Predicted=19.076772, Expected=19.090000
# Minute=42989, Predicted=19.076771, Expected=19.090000
# Minute=42990, Predicted=19.076771, Expected=19.090000
# Minute=42991, Predicted=19.076771, Expected=19.090000
# Minute=42992, Predicted=19.076772, Expected=19.090000
# Minute=42993, Predicted=19.076771, Expected=18.840000
# Minute=42994, Predicted=18.826772, Expected=18.840000
# Minute=42995, Predicted=18.826771, Expected=18.840000
# Minute=42996, Predicted=18.826771, Expected=18.840000
# Minute=42997, Predicted=18.826771, Expected=18.840000
# Minute=42998, Predicted=18.826772, Expected=18.840000
# Minute=42999, Predicted=18.826771, Expected=18.840000
# Minute=43000, Predicted=18.826772, Expected=18.890000
# Minute=43001, Predicted=18.876771, Expected=18.890000
# Minute=43002, Predicted=18.876771, Expected=18.890000
# Minute=43003, Predicted=18.876771, Expected=18.890000
# Minute=43004, Predicted=18.876772, Expected=18.890000
# Minute=43005, Predicted=18.876771, Expected=18.890000
# Minute=43006, Predicted=18.876772, Expected=18.890000
# Minute=43007, Predicted=18.876771, Expected=17.950000
# Minute=43008, Predicted=17.936771, Expected=17.950000
# Minute=43009, Predicted=17.936771, Expected=17.950000
# Minute=43010, Predicted=17.936772, Expected=17.950000
# Minute=43011, Predicted=17.936771, Expected=17.950000
# Minute=43012, Predicted=17.936772, Expected=17.950000
# Minute=43013, Predicted=17.936771, Expected=18.240000
# Minute=43014, Predicted=18.226771, Expected=18.240000
# Minute=43015, Predicted=18.226771, Expected=18.240000
# Minute=43016, Predicted=18.226772, Expected=18.240000
# Minute=43017, Predicted=18.226771, Expected=18.240000
# Minute=43018, Predicted=18.226772, Expected=18.240000
# Minute=43019, Predicted=18.226771, Expected=18.240000
# Minute=43020, Predicted=18.226771, Expected=18.370000
# Minute=43021, Predicted=18.356771, Expected=18.370000
# Minute=43022, Predicted=18.356772, Expected=18.370000
# Minute=43023, Predicted=18.356771, Expected=18.370000
# Minute=43024, Predicted=18.356772, Expected=18.370000
# Minute=43025, Predicted=18.356771, Expected=18.370000
# Minute=43026, Predicted=18.356771, Expected=18.370000
# Minute=43027, Predicted=18.356771, Expected=18.570000
# Minute=43028, Predicted=18.556772, Expected=18.570000
# Minute=43029, Predicted=18.556771, Expected=18.570000
# Minute=43030, Predicted=18.556772, Expected=18.570000
# Minute=43031, Predicted=18.556771, Expected=18.570000
# Minute=43032, Predicted=18.556771, Expected=18.570000
# Minute=43033, Predicted=18.556771, Expected=18.570000
# Minute=43034, Predicted=18.556772, Expected=17.670000
# Minute=43035, Predicted=17.656771, Expected=17.670000
# Minute=43036, Predicted=17.656772, Expected=17.670000
# Minute=43037, Predicted=17.656771, Expected=17.670000
# Minute=43038, Predicted=17.656771, Expected=17.670000
# Minute=43039, Predicted=17.656771, Expected=17.670000
# Minute=43040, Predicted=17.656772, Expected=18.020000
# Minute=43041, Predicted=18.006771, Expected=18.020000
# Minute=43042, Predicted=18.006772, Expected=18.020000
# Minute=43043, Predicted=18.006771, Expected=18.020000
# Minute=43044, Predicted=18.006771, Expected=18.020000
# Minute=43045, Predicted=18.006771, Expected=18.020000
# Minute=43046, Predicted=18.006772, Expected=18.020000
# Minute=43047, Predicted=18.006771, Expected=18.020000
# Minute=43048, Predicted=18.006772, Expected=18.020000
# Minute=43049, Predicted=18.006771, Expected=18.020000
# Minute=43050, Predicted=18.006771, Expected=18.020000
# Minute=43051, Predicted=18.006771, Expected=18.020000
# Minute=43052, Predicted=18.006772, Expected=18.020000
# Minute=43053, Predicted=18.006771, Expected=18.020000
# Minute=43054, Predicted=18.006772, Expected=17.580000
# Minute=43055, Predicted=17.566771, Expected=17.580000
# Minute=43056, Predicted=17.566771, Expected=17.580000
# Minute=43057, Predicted=17.566771, Expected=17.580000
# Minute=43058, Predicted=17.566772, Expected=17.580000
# Minute=43059, Predicted=17.566771, Expected=17.580000
# Minute=43060, Predicted=17.566772, Expected=17.580000
# Minute=43061, Predicted=17.566771, Expected=17.320000
# Minute=43062, Predicted=17.306771, Expected=17.320000
# Minute=43063, Predicted=17.306771, Expected=17.320000
# Minute=43064, Predicted=17.306772, Expected=17.320000
# Minute=43065, Predicted=17.306771, Expected=17.320000
# Minute=43066, Predicted=17.306772, Expected=17.320000
# Minute=43067, Predicted=17.306771, Expected=17.240000
# Minute=43068, Predicted=17.226771, Expected=17.240000
# Minute=43069, Predicted=17.226771, Expected=17.240000
# Minute=43070, Predicted=17.226772, Expected=17.240000
# Minute=43071, Predicted=17.226771, Expected=17.240000
# Minute=43072, Predicted=17.226772, Expected=17.240000
# Minute=43073, Predicted=17.226771, Expected=17.240000
# Minute=43074, Predicted=17.226771, Expected=18.850000
# Minute=43075, Predicted=18.836771, Expected=18.850000
# Minute=43076, Predicted=18.836772, Expected=18.850000
# Minute=43077, Predicted=18.836771, Expected=18.850000
# Minute=43078, Predicted=18.836772, Expected=18.850000
# Minute=43079, Predicted=18.836771, Expected=18.850000
# Minute=43080, Predicted=18.836771, Expected=18.850000
# Minute=43081, Predicted=18.836771, Expected=19.640000
# Minute=43082, Predicted=19.626772, Expected=19.640000
# Minute=43083, Predicted=19.626771, Expected=19.640000
# Minute=43084, Predicted=19.626772, Expected=19.640000
# Minute=43085, Predicted=19.626771, Expected=19.640000
# Minute=43086, Predicted=19.626771, Expected=19.640000
# Minute=43087, Predicted=19.626771, Expected=19.640000
# Minute=43088, Predicted=19.626772, Expected=19.580000
# Minute=43089, Predicted=19.566771, Expected=19.580000
# Minute=43090, Predicted=19.566772, Expected=19.580000
# Minute=43091, Predicted=19.566771, Expected=19.580000
# Minute=43092, Predicted=19.566771, Expected=19.580000
# Minute=43093, Predicted=19.566771, Expected=19.580000
# Minute=43094, Predicted=19.566772, Expected=19.580000
# Minute=43095, Predicted=19.566771, Expected=19.640000
# Minute=43096, Predicted=19.626772, Expected=19.640000
# Minute=43097, Predicted=19.626771, Expected=19.640000
# Minute=43098, Predicted=19.626771, Expected=19.640000
# Minute=43099, Predicted=19.626771, Expected=19.640000
# Minute=43100, Predicted=19.626772, Expected=19.640000
# Minute=43101, Predicted=19.626771, Expected=20.410000
# Minute=43102, Predicted=20.396772, Expected=20.410000
# Minute=43103, Predicted=20.396771, Expected=20.410000
# Minute=43104, Predicted=20.396771, Expected=20.410000
# Minute=43105, Predicted=20.396771, Expected=20.410000
# Minute=43106, Predicted=20.396772, Expected=20.410000
# Minute=43107, Predicted=20.396771, Expected=21.260000
# Minute=43108, Predicted=21.246772, Expected=21.260000
# Minute=43109, Predicted=21.246771, Expected=21.260000
# Minute=43110, Predicted=21.246771, Expected=21.260000
# Minute=43111, Predicted=21.246771, Expected=21.260000
# Minute=43112, Predicted=21.246772, Expected=21.260000
# Minute=43113, Predicted=21.246771, Expected=21.260000
# Minute=43114, Predicted=21.246772, Expected=21.260000
# Minute=43115, Predicted=21.246771, Expected=21.260000
# Minute=43116, Predicted=21.246771, Expected=21.260000
# Minute=43117, Predicted=21.246771, Expected=21.260000
# Minute=43118, Predicted=21.246772, Expected=21.260000
# Minute=43119, Predicted=21.246771, Expected=21.260000
# Minute=43120, Predicted=21.246772, Expected=21.260000
# Minute=43121, Predicted=21.246771, Expected=21.260000
# Minute=43122, Predicted=21.246771, Expected=21.260000
# Minute=43123, Predicted=21.246771, Expected=21.260000
# Minute=43124, Predicted=21.246772, Expected=21.260000
# Minute=43125, Predicted=21.246771, Expected=21.260000
# Minute=43126, Predicted=21.246772, Expected=21.260000
# Minute=43127, Predicted=21.246771, Expected=21.260000
# Minute=43128, Predicted=21.246771, Expected=21.160000
# Minute=43129, Predicted=21.146771, Expected=21.160000
# Minute=43130, Predicted=21.146772, Expected=21.160000
# Minute=43131, Predicted=21.146771, Expected=21.160000
# Minute=43132, Predicted=21.146772, Expected=21.160000
# Minute=43133, Predicted=21.146771, Expected=21.160000
# Minute=43134, Predicted=21.146771, Expected=21.160000
# Minute=43135, Predicted=21.146771, Expected=20.510000
# Minute=43136, Predicted=20.496772, Expected=20.510000
# Minute=43137, Predicted=20.496771, Expected=20.510000
# Minute=43138, Predicted=20.496772, Expected=20.510000
# Minute=43139, Predicted=20.496771, Expected=20.510000
# Minute=43140, Predicted=20.496771, Expected=20.510000
# Minute=43141, Predicted=20.496771, Expected=20.510000
# Minute=43142, Predicted=20.496772, Expected=20.510000
# Minute=43143, Predicted=20.496771, Expected=20.510000
# Minute=43144, Predicted=20.496772, Expected=20.510000
# Minute=43145, Predicted=20.496771, Expected=20.510000
# Minute=43146, Predicted=20.496771, Expected=20.510000
# Minute=43147, Predicted=20.496771, Expected=20.510000
# Minute=43148, Predicted=20.496772, Expected=20.060000
# Minute=43149, Predicted=20.046771, Expected=20.060000
# Minute=43150, Predicted=20.046772, Expected=20.060000
# Minute=43151, Predicted=20.046771, Expected=20.060000
# Minute=43152, Predicted=20.046771, Expected=20.060000
# Minute=43153, Predicted=20.046771, Expected=20.060000
# Minute=43154, Predicted=20.046772, Expected=20.060000
# Minute=43155, Predicted=20.046771, Expected=19.590000
# Minute=43156, Predicted=19.576772, Expected=19.590000
# Minute=43157, Predicted=19.576771, Expected=19.590000
# Minute=43158, Predicted=19.576771, Expected=19.590000
# Minute=43159, Predicted=19.576771, Expected=19.590000
# Minute=43160, Predicted=19.576772, Expected=19.590000
# Minute=43161, Predicted=19.576771, Expected=19.520000
# Minute=43162, Predicted=19.506772, Expected=19.520000
# Minute=43163, Predicted=19.506771, Expected=19.520000
# Minute=43164, Predicted=19.506771, Expected=19.520000
# Minute=43165, Predicted=19.506771, Expected=19.520000
# Minute=43166, Predicted=19.506772, Expected=19.520000
# Minute=43167, Predicted=19.506771, Expected=19.960000
# Minute=43168, Predicted=19.946772, Expected=19.960000
# Minute=43169, Predicted=19.946771, Expected=19.960000
# Minute=43170, Predicted=19.946771, Expected=19.960000
# Minute=43171, Predicted=19.946771, Expected=19.960000
# Minute=43172, Predicted=19.946772, Expected=19.960000
# Minute=43173, Predicted=19.946771, Expected=20.020000
# Minute=43174, Predicted=20.006772, Expected=20.020000
# Minute=43175, Predicted=20.006771, Expected=20.020000
# Minute=43176, Predicted=20.006771, Expected=20.020000
# Minute=43177, Predicted=20.006771, Expected=20.020000
# Minute=43178, Predicted=20.006772, Expected=20.020000
# Minute=43179, Predicted=20.006771, Expected=20.020000
# Minute=43180, Predicted=20.006772, Expected=19.800000
# Minute=43181, Predicted=19.786771, Expected=19.800000
# Minute=43182, Predicted=19.786771, Expected=19.800000
# Minute=43183, Predicted=19.786771, Expected=19.800000
# Minute=43184, Predicted=19.786772, Expected=19.800000
# Minute=43185, Predicted=19.786771, Expected=19.800000
# Minute=43186, Predicted=19.786772, Expected=19.800000
# Minute=43187, Predicted=19.786771, Expected=19.800000
# Minute=43188, Predicted=19.786771, Expected=19.800000
# Minute=43189, Predicted=19.786771, Expected=19.800000
# Minute=43190, Predicted=19.786772, Expected=19.800000
# Minute=43191, Predicted=19.786771, Expected=19.800000
# Minute=43192, Predicted=19.786772, Expected=19.800000
# Minute=43193, Predicted=19.786771, Expected=19.800000
# Minute=43194, Predicted=19.786771, Expected=19.800000
# Minute=43195, Predicted=19.786771, Expected=19.800000
# Minute=43196, Predicted=19.786772, Expected=19.800000
# Minute=43197, Predicted=19.786771, Expected=19.800000
# Minute=43198, Predicted=19.786772, Expected=19.800000
# Minute=43199, Predicted=19.786771, Expected=19.800000
# Minute=43200, Predicted=19.786771, Expected=19.800000
# Mean Absolute Percent Error:  0.004239287105323245

# %%
# line plot of observed vs predicted

#sns.set_style("whitegrid")
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(20,10))
plt.plot(expectations_plot[:predict_values_exp], label="True")
plt.plot(predictions_plot[:predict_values_exp], label="Predicted")
plt.legend(loc='upper right')
plt.xlabel("Number of Minutes")
plt.ylabel("Energy Demand")
plt.savefig('img/Model_prediction.png')
#plt.show()
